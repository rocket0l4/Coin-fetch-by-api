# %% [markdown]
# <a href="https://colab.research.google.com/github/rocket0l4/Coin-fetch-by-api/blob/main/Flow_diagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Reorganizing layout manually for a clearer flow diagram
# Assign specific positions to avoid overlap and ensure clarity

manual_pos = {
    "Project Planning": (0, 10),
    "Data Collection": (2, 8),
    "Data Preprocessing": (4, 6),
    "Model Architecture Design": (6, 4),
    "Trading Strategy Development": (8, 2),
    "Backtesting Framework": (10, 0),
    "Model Training & Tuning": (8, -2),
    "Model Evaluation": (6, -4),
    "Real-Time System Integration": (4, -6),
    "Testing & Performance Review": (2, -8),
    "Deployment & Maintenance": (0, -10),
}

# Plot the manually positioned graph
plt.figure(figsize=(14, 12))
nx.draw_networkx_nodes(G, manual_pos, node_size=4000, node_color="lightblue")
nx.draw_networkx_edges(G, manual_pos, edgelist=dependencies, arrowstyle="->", arrowsize=20, edge_color="gray")
nx.draw_networkx_labels(G, manual_pos, font_size=12, font_color="black", font_weight="bold")

plt.title("Neat and Clean Flow Diagram Based on Gantt Chart Tasks", fontsize=16)
plt.axis("off")
plt.show()
